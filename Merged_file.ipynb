# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                      property_name property_type  \
# 0                              2 BHK Flat in Sohna          flat
# 1                 2 BHK Flat in Sector 70A Gurgaon          flat
# 2  6 Bedroom House for sale in Sushant Lok Phase 3         house
# 3      5 Bedroom House for sale in Nirvana Country         house
# 4          5 Bedroom House for sale in DLF Phase 2         house
#
#                   society  price  price_per_sqft    area  \
# 0  breez global hill view   0.30          5124.0   585.0
# 1    aipl club residences   0.95         10215.0   930.0
# 2   ansals florence villa   3.65         10579.0  3450.0
# 3     nirvana cedar crest   7.10         32870.0  2160.0
# 4             independent  13.50         37313.0  3618.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                  Carpet area: 585.41 (54.39 sq.m.)        2         2
# 1  Built Up area: 930 (86.4 sq.m.)Carpet area: 73...        2         2
# 2                       Plot area 3450(320.52 sq.m.)        6         6
# 3  Plot area 240(200.67 sq.m.)Built Up area: 239 ...        5         4
# 4                        Plot area 402(336.12 sq.m.)        5         6
#
#   balcony                                 additionalRoom  \
# 0       1                                  not available
# 1       1                                  not available
# 2       2  pooja room,study room,servant room,store room
# 3       3               store room,pooja room,study room
# 4      3+                                         others
#
#                                              address  floorNum      facing  \
# 0                            Sohna, Gurgaon, Haryana      11.0       North
# 1   Sector 70a, Sector 70A Gurgaon, Gurgaon, Haryana      11.0  North-East
# 2     E-Block, Sushant Lok Phase 3, Gurgaon, Haryana       3.0  North-West
# 3  240 Sq Yd, Ground And First Floor At 7.10 Cr, ...       2.0        East
# 4                      DLF Phase 2, Gurgaon, Haryana       4.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 1   0 to 1 Year Old  ['Airia Mall', 'Golf Corse Ext. Rd', 'National...
# 2  5 to 10 Year Old  ['Sector metro station', 'Sector metro station...
# 3  5 to 10 Year Old  ['Standard chartered ATM', 'Icici bank ATM', '...
# 4      10+ Year Old  ['Vodafone belvedere towers metro station', 'D...
#
#                                          description  \
# 0  Residential apartment for sell located sector ...
# 1  Gurgaon one of the best in class property avai...
# 2  6bedrooms 6baths\nIndependent house/villa for ...
# 3  This is residential house for sale in the very...
# 4  Luxurious villa on 402 sq yard plot in dlf pha...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1  ['11 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 G...
# 2  ['1 Water Purifier', '1 Fan', '1 Fridge', '1 E...
# 3  ['3 Wardrobe', '1 Water Purifier', '6 Fan', '1...
# 4  ['10 Wardrobe', '1 Water Purifier', '12 Fan', ...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2  ['Water purifier', 'Centrally Air Conditioned'...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Security / Fire Alarm', 'Water purifier', 'S...
#
#                                               rating
# 0  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 1  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
